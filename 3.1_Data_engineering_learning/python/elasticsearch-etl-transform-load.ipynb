# %% [markdown]
# # Demo : ETL Elasticsearch (Transform-Load)

# %% [markdown]
# Import libraries. At this point, you should already runs previous lessons and have the libraries installed.

# %%
import pandas as pd
import psycopg2
from elasticsearch import Elasticsearch
from pprint import pprint

# %% [markdown]
# Open connection to postgresql

# %%
try:
    conn = psycopg2.connect("host=34.101.229.192 dbname=postgres user=postgres password=CourseDE888")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
except Exception as e:
    print("Error: cannot open cursor for SQL interaction")
    print(e)

# %% [markdown]
# Open connection to elasticsearch

# %%
try:
    es = Elasticsearch(
            hosts=["https://data-engineering.es.asia-southeast1.gcp.elastic-cloud.com:9243"], 
            http_auth=("elastic", "piBb8K7c0ATizq5R725uRy8N")
         )
except Exception as e:
    print("Error: cannot open cursor for Elasticsearch interaction")
    print(e)

# %% [markdown]
# Populate data for staging tables

# %%
sql_movie_principals = "SELECT * FROM staging.stg_es_movie_principals"

# %%
df_movie_principals = pd.read_sql(sql_movie_principals, conn)

# %% [markdown]
# Index name will be used later.

# %%
es_index_name = "movie-principals"

# %% [markdown]
# Optionally, create index with manual setting.

# %%
es_index_body = """
{
  "settings": {
    "number_of_shards": 3,
    "number_of_replicas": 2
  }
}
"""

try:
    es.indices.create(es_index_name, body=es_index_body)
except Exception as e:
    print(e)

# %% [markdown]
# For the demo, just take 10,000 data

# %%
df_movie_principals = df_movie_principals.sample(10000)

# %% [markdown]
# Note that we might have data like this from staging.
#
# | title_id  | name_id  | category  | job  | character  |
# |---|---|---|---|---|
# | title01  | name99  | AAA  |   |   |
# | title01  | name99  |   | BBB  |   |
# | title01  | name99  |   | CCC  |   |
# | title01  | name99  |   |   | DDD  |
#
# So the only transformation we need, is aggregate such data into one row. On example above, column `Job` also joined by comma, so we have
#
# | title_id  | name_id  | category  | job  | character  |
# |---|---|---|---|---|
# | title01  | name99  | AAA  | BBB, CCC  | DDD  |

# %%
f_agg = lambda x: ', '.join(x.dropna().unique())
df_movie_principals = df_movie_principals.groupby(['title_id','name_id'], as_index=False).agg(f_agg)

# %% [markdown]
# See the aggregated sample.

# %%
df_movie_principals.sample(5)
# Out:
#        title_id    name_id                                   title  \
# 5665  tt0467110  nm0227759  Underdog - Storia di un vero supereroe
# 6853  tt1450320  nm0752117                          Días de gracia
# 2822  tt0094169  nm0322946                      I duri non ballano
# 8622  tt4183372  nm5667278                      De Onde Eu Te Vejo
# 5240  tt0382810  nm0675476          Little Fish - Fuga dall'incubo
#
#               original_title        production_company  \
# 5665                Underdog  Have No Fear Productions
# 6853          Días de gracia             ARP Sélection
# 2822  Tough Guys Don't Dance  Golan-Globus Productions
# 8622      De Onde Eu Te Vejo          Bossa Nova Films
# 5240             Little Fish          Porchlight Films
#
#                                             description              name  \
# 5665  A Beagle must use his newly-bestowed superpowe...    Peter Dinklage
# 6853  Mexico City. 2002, 2006, 2010. A cop. A hostag...     David Rutsala
# 2822  Writer, ex-con and 40-something bottle-baby Ti...      Yoram Globus
# 8622  After 20 years of marriage, Ana Lúcia and her ...  Leonardo Moreira
# 5240  Set in the Little Saigon district outside of S...  Jacquelin Perske
#
#       category                 job character
# 5665     actor
# 6853            additional writing
# 2822  producer
# 8622    writer
# 5240                    written by

# %% [markdown]
# Load aggregated data into Elasticsearch, using our own id.

# %%
for idx, rec in df_movie_principals.iterrows():
    key = "{}-{}".format(rec["title_id"], rec["name_id"].lower().replace(" ", ""))
    es.index(es_index_name, rec.to_json(), id=key)

# %% [markdown]
# Simple query demo

# %%
search_body = '''
{
    "query": {
        "match": {
            "title": "love"
        }
    }
}
'''

res = es.search(index=es_index_name, body=search_body)
pprint(res)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 3, 'total': 3},
#  'hits': {'hits': [{'_id': 'tt0392360-nm0006795',
#                     '_index': 'movie-principals',
#                     '_score': 7.18776,
#                     '_source': {'category': '',
#                                 'character': 'Prithvi',
#                                 'description': 'Prithvi and Maggie fall in '
#                                                'love and decide to get '
#                                                "married, but Maggie's mother "
#                                                "objects looking at Prithvi's "
#                                                'past.',
#                                 'job': '',
#                                 'name': 'Salman Khan',
#                                 'name_id': 'nm0006795',
#                                 'original_title': 'Love',
#                                 'production_company': 'Unknown',
#                                 'title': 'Love',
#                                 'title_id': 'tt0392360'},
#                     '_type': '_doc'},
#                    {'_id': 'tt5457078-nm0578857',
#                     '_index': 'movie-principals',
#                     '_score': 6.703971,
#                     '_source': {'category': 'writer',
#                                 'character': '',
#                                 'description': 'Following the death of their '
#                                                'father, two sons deal with the '
#                                                'trials of their own lives '
#                                                'while watching their mother '
#                                                'explore new beginnings of her '
#                                                'own.',
#                                 'job': '',
#                                 'name': 'Eric Mendelsohn',
#                                 'name_id': 'nm0578857',
#                                 'original_title': 'Love After Love',
#                                 'production_company': 'Secret Engine',
#                                 'title': 'Love After Love',
#                                 'title_id': 'tt5457078'},
#                     '_type': '_doc'},
#                    {'_id': 'tt2303626-nm2296992',
#                     '_index': 'movie-principals',
#                     '_score': 6.0334663,
#                     '_source': {'category': 'director',
#                                 'character': '',
#                                 'description': "How rock 'n' roll survived in "
#                                                'Yellow Cab.',
#                                 'job': '',
#                                 'name': 'Nemanja Bala',
#                                 'name_id': 'nm2296992',
#                                 'original_title': 'Love Hunter',
#                                 'production_company': 'Love Hunter Films',
#                                 'title': 'Love Hunter',
#                                 'title_id': 'tt2303626'},
#                     '_type': '_doc'},
#                    {'_id': 'tt2792332-nm1890655',
#                     '_index': 'movie-principals',
#                     '_score': 6.0334663,
#                     '_source': {'category': 'actor',
#                                 'character': '',
#                                 'description': 'Love Building is a camp '
#                                                'designed to mend broken '
#                                                'relationships. 14 couples in '
#                                                'the program have 7 days to '
#                                                're-design their love lives. '
#                                                'But the 3 trainers meant to '
#                                                'assist them have problems of '
#                                                'their own and things gradually '
#                                                'get out of hand.',
#                                 'job': '',
#                                 'name': 'Dorian Boguta',
#                                 'name_id': 'nm1890655',
#                                 'original_title': 'Love Building',
#                                 'production_company': 'ActorieDeFilm',
#                                 'title': 'Love Building',
#                                 'title_id': 'tt2792332'},
#                     '_type': '_doc'},
#                    {'_id': 'tt3421318-nm7461852',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': '',
#                                 'character': '',
#                                 'description': 'When his wife dies during '
#                                                'childbirth, a man takes up her '
#                                                'favorite sport, tennis, in an '
#                                                'effort to hold onto her '
#                                                'memory. He focuses on winning '
#                                                'tournaments and neglects his '
#                                                'newborn daughter. A family '
#                                                'tug-of-war begins for control '
#                                                'of his baby.',
#                                 'job': 'producer',
#                                 'name': 'Lisa Rau',
#                                 'name_id': 'nm7461852',
#                                 'original_title': '30-Love',
#                                 'production_company': 'Cannonball of Death',
#                                 'title': '30-Love',
#                                 'title_id': 'tt3421318'},
#                     '_type': '_doc'},
#                    {'_id': 'tt1474271-nm3534427',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': '',
#                                 'character': '',
#                                 'description': 'A talented Sous-Chef woos a '
#                                                'variety of women with a view '
#                                                'of using them to try and '
#                                                'fulfill his dream.',
#                                 'job': 'story & screenplay',
#                                 'name': 'Manu Joseph',
#                                 'name_id': 'nm3534427',
#                                 'original_title': 'Love Khichdi',
#                                 'production_company': 'Pittie Group',
#                                 'title': 'Love Khichdi',
#                                 'title_id': 'tt1474271'},
#                     '_type': '_doc'},
#                    {'_id': 'tt2960270-nm9255765',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': '',
#                                 'character': 'Fr Abendroth',
#                                 'description': 'Luxury hotel. Luxury '
#                                                'clientele. Irritable staff. A '
#                                                'couple who might fall in love, '
#                                                'or they might leave their '
#                                                'relationship in its raw state '
#                                                '- like the titular steaks.',
#                                 'job': '',
#                                 'name': 'Kerstin Abendroth',
#                                 'name_id': 'nm9255765',
#                                 'original_title': 'Love Steaks',
#                                 'production_company': 'Hochschule für Film und '
#                                                       "Fernsehen 'Konrad Wolf'",
#                                 'title': 'Love Steaks',
#                                 'title_id': 'tt2960270'},
#                     '_type': '_doc'},
#                    {'_id': 'tt0847510-nm1139421',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': '',
#                                 'character': 'Lulu',
#                                 'description': 'A surreal drama about an '
#                                                'alienated family set in '
#                                                'Koreatown, Los Angeles and '
#                                                'Rishikesh, India.',
#                                 'job': '',
#                                 'name': 'Marina Shoif',
#                                 'name_id': 'nm1139421',
#                                 'original_title': 'Phantom Love',
#                                 'production_company': 'KNR Productions',
#                                 'title': 'Phantom Love',
#                                 'title_id': 'tt0847510'},
#                     '_type': '_doc'},
#                    {'_id': 'tt5569468-nm1127958',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': 'actor',
#                                 'character': '',
#                                 'description': 'The story of Love Punjab '
#                                                'revolves around a family in '
#                                                'which husband and wife fights '
#                                                'daily for small reasons and '
#                                                'their son is only victim of '
#                                                'these fights. After suffering '
#                                                'from all these ...',
#                                 'job': '',
#                                 'name': 'Yograj Singh',
#                                 'name_id': 'nm1127958',
#                                 'original_title': 'Love Punjab',
#                                 'production_company': 'Rhythm Boyz '
#                                                       'Entertainment',
#                                 'title': 'Love Punjab',
#                                 'title_id': 'tt5569468'},
#                     '_type': '_doc'},
#                    {'_id': 'tt0353675-nm0031896',
#                     '_index': 'movie-principals',
#                     '_score': 5.8407536,
#                     '_source': {'category': '',
#                                 'character': 'Self',
#                                 'description': 'Mridula and Arun are a young '
#                                                'couple, who meet accidentally, '
#                                                'and fall in love with each '
#                                                'other. Both come from wealthy '
#                                                'families, and are reluctant to '
#                                                'get married unless they find '
#                                                'out if they ...',
#                                 'job': '',
#                                 'name': 'Apache Indian',
#                                 'name_id': 'nm0031896',
#                                 'original_title': 'Love Birds',
#                                 'production_company': 'Pyramid Films',
#                                 'title': 'Love Birds',
#                                 'title_id': 'tt0353675'},
#                     '_type': '_doc'}],
#           'max_score': 7.18776,
#           'total': {'relation': 'eq', 'value': 62}},
#  'timed_out': False,
#  'took': 2}
